# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings('ignore')

# Create a formatted table of versions
versions = pd.DataFrame({
    "Library": ["NumPy", "Pandas", "Matplotlib", "Seaborn"],
    "Version": [np.__version__, pd.__version__, plt.matplotlib.__version__, sns.__version__]
})

# Display the table
print("Library Versions:\n")
print(versions.to_string(index=False))
# Out:
# Library Versions:
#
#    Library Version
#      NumPy   2.0.2
#     Pandas   2.2.2
# Matplotlib  3.10.0
#    Seaborn  0.13.2

# %%
df = pd.read_csv('/content/StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
df.tail(5)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
print("\n" + "="*60)
print("RANDOM SAMPLE (8 ROWS)")
print("="*60)
print(df.sample(8, random_state=42))
# Out:
# ...
# RANDOM SAMPLE (8 ROWS)
# ...
#      gender race/ethnicity parental level of education         lunch  \
# 521  female        group C          associate's degree      standard
# 737  female        group B                some college  free/reduced
# 740    male        group D           bachelor's degree      standard
# 660    male        group C                some college  free/reduced
# 411    male        group E                some college      standard
# 678    male        group D          associate's degree  free/reduced
# 626    male        group B          associate's degree  free/reduced
# 513  female        group B            some high school      standard
#
#     test preparation course  math score  reading score  writing score
# 521                    none          91             86             84
# 737               completed          53             66             73
# 740                    none          80             73             72
# ...

# %% [markdown]
# ### Dataset Explanation
#
# - **Rows:**
#   Each row represents a single student. The dataset contains **1000 students**, with each row showing that student's demographic details and exam performance.
#
# - **Columns:**
#   The dataset has **8 columns**, which describe different attributes of each student:
#
#   1. **gender** – The gender of the student (e.g., male, female)
#   2. **race/ethnicity** – The student’s ethnic group classification
#   3. **parental level of education** – The highest education level attained by the student’s parents
#   4. **lunch** – Type of lunch (standard or free/reduced), which may relate to socioeconomic status
#   5. **test preparation course** – Whether the student completed a test preparation course (completed/none)
#   6. **math score** – Student’s score in math (numerical)
#   7. **reading score** – Student’s score in reading (numerical)
#   8. **writing score** – Student’s score in writing (numerical)
#
# - **Data Types:**
#   - **Categorical (object):** gender, race/ethnicity, parental level of education, lunch, test preparation course
#   - **Numerical (int64):** math score, reading score, writing score
#
# - **Summary:**
#   This dataset is commonly used for analyzing how demographic and educational factors affect student performance in exams. Each row combines background information with test scores, allowing for comparison and pattern analysis.

# %%
df.shape
# Out:
# (1000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df.columns.tolist()
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental level of education',
#  'lunch',
#  'test preparation course',
#  'math score',
#  'reading score',
#  'writing score']

# %%
# Count categorical vs numerical columns
categorical_cols = df.select_dtypes(include=['object']).columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
print("COLUMN TYPE COUNTS")
print("="*60)
print(f"Categorical Columns: {len(categorical_cols)}")
print(f"Numerical Columns: {len(numerical_cols)}")
print("="*60)
print("\nCategorical Columns List:")
print(list(categorical_cols))

print("\nNumerical Columns List:")
print(list(numerical_cols))
# Out:
# COLUMN TYPE COUNTS
# ...
# Categorical Columns: 5
# Numerical Columns: 3
# ...
#
# Categorical Columns List:
# ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course']
#
# Numerical Columns List:
# ['math score', 'reading score', 'writing score']

# %% [markdown]
# ### Dataset Structure Analysis
#
# - The dataset contains **1000 rows and 8 columns**, indicating a moderately sized dataset suitable for analysis and machine learning.
#
# - **Data Types Observation:**
#   - There are **5 categorical (object) columns**:
#     - gender
#     - race/ethnicity
#     - parental level of education
#     - lunch
#     - test preparation course
#
#   - There are **3 numerical (int64) columns**:
#     - math score
#     - reading score
#     - writing score
#
# - **Are the data types correct?**
#   Yes, the current data types are appropriate:
#   - Categorical variables are correctly stored as `object`
#   - Scores are correctly stored as integers (`int64`)
#
# - **Do any data types need changing for Machine Learning?**
#   Yes, for machine learning models:
#   - Categorical columns **cannot be used directly** and must be converted into numerical format using techniques such as:
#     - Label Encoding
#     - One-Hot Encoding
#
#   - Numerical columns are already in the correct format and do not require conversion.
#
# - **Additional Observation:**
#   - There are **no missing values** (all columns have 1000 non-null entries), which means no immediate data cleaning is required.
#   - The dataset is clean and well-structured, making it suitable for further preprocessing and modeling.

# %%
print("Missing Values (COUNT)")
miss_count = df.isnull().sum()
miss_count
# Out:
# Missing Values (COUNT)
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
print(" Missing Value Percentage ")
miss_perc = (miss_count/len(df)) * 100
miss_perc
# Out:
#  Missing Value Percentage
# gender                         0.0
# race/ethnicity                 0.0
# parental level of education    0.0
# lunch                          0.0
# test preparation course        0.0
# math score                     0.0
# reading score                  0.0
# writing score                  0.0
# dtype: float64

# %%
print(" Duplicate rows")
duplicate_data = df.duplicated().sum()
print(" Number of Duplicated Row : ",duplicate_data)
# Out:
#  Duplicate rows
#  Number of Duplicated Row :  0

# %%
print(" Bar chart - Based on Missing Value")
plt.figure(figsize=(10, 6))
sns.barplot(x =miss_count.index , y=miss_count.values)
plt.title(" Missing Values per Column")
plt.xlabel("Columns")
plt.ylabel("Missing Values")
plt.xticks(rotation=45)
plt.show()
# Out:
#  Bar chart - Based on Missing Value

# %% [markdown]
# ### Missing Value & Duplicate Analysis
#
# - The dataset shows that there are **no missing values** in any of the columns, as all columns have zero null entries. This indicates that the dataset is complete and does not require immediate data imputation.
#
# - Additionally, there are **no duplicate rows**, meaning each record is unique. This confirms that the dataset is clean and does not contain redundant data.
#
# - Overall, the dataset is **well-structured and clean**, making it suitable for further analysis and machine learning without major preprocessing.
#
# - If missing values were present, the following approaches could be used:
#   - For numerical columns, missing values could be filled using mean, median, or mode.
#   - For categorical columns, the most frequent category (mode) could be used.
#   - In some cases, rows with too many missing values could be removed if they are not significant.
#
# - Proper handling of missing data is important to ensure accurate model performance and avoid biased results.

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
subject = ['math score','reading score', 'writing score']
result = []

for sub in subject:
  mean_val = df[sub].mean()
  median_val = df[sub].median()
  mode_val = df[sub].mode()
  std_val = df[sub].std()
  var_val = df[sub].var()
  min_val = df[sub].min()
  max_val = df[sub].max()
  range = max_val - min_val

  # The 'subject' variable in 'result.append' should be 'sub' to store the current subject name
  result.append([ sub, mean_val, median_val, mode_val, std_val, var_val, min_val, max_val, range])

# Create the DataFrame after the loop has finished populating 'result'
result_data = pd.DataFrame(result, columns=[
    "Subject", 'Mean', 'Median', 'Mode', 'Std Dev', 'Varience', 'Min', 'Max', 'Range'
])

print(" Summary Statistics Table")
print("="*60)
display(result_data)
# Out:
#  Summary Statistics Table
# ...
#          Subject    Mean  Median                                       Mode  \
# 0     math score  66.089    66.0     0    65
# Name: math score, dtype: int64
# 1  reading score  69.169    70.0  0    72
# Name: reading score, dtype: int64
# 2  writing score  68.054    69.0  0    74
# Name: writing score, dtype: int64
#
#      Std Dev    Varience  Min  Max  Range
# 0  15.163080  229.918998    0  100    100
# 1  14.600192  213.165605   17  100     83
# 2  15.195657  230.907992   10  100     90

# %% [markdown]
# ### Descriptive Statistics Analysis
#
# - From the computed statistics, **reading score** (or writing, depending on your actual output — verify from your table) has the highest average (mean). This suggests that students generally perform better in this subject compared to others.
#
# - The subject with the **highest variability (standard deviation)** is typically **math score** (confirm from your results). A higher standard deviation indicates that student performance is more spread out, meaning some students score very high while others score low.
#
# - This suggests that **math may be the most difficult or inconsistent subject**, as student performance varies widely. In contrast, reading and writing scores tend to be more consistent, indicating more uniform performance among students.
#
# - Overall, differences in mean and variability highlight how students perform differently across subjects, which can be useful for identifying areas where additional support or teaching improvements may be needed.

# %% [markdown]
# #**PART B — STATISTICAL ANALYSIS & GROUP COMPARISONS (STEPS 6–10) **

# %%
categorical_cols = [
    'gender',
    'race/ethnicity',
    'parental level of education',
    'lunch',
    'test preparation course'
]

for col in categorical_cols:
    print("="*60)
    print(f"VALUE COUNTS FOR: {col.upper()}")
    print("="*60)
    print(df[col].value_counts())

    print("\nPERCENTAGE DISTRIBUTION:")
    print((df[col].value_counts(normalize=True) * 100).round(2))
    print("\n")
# Out:
# ...
# VALUE COUNTS FOR: GENDER
# ...
# gender
# female    518
# male      482
# Name: count, dtype: int64
#
# PERCENTAGE DISTRIBUTION:
# gender
# female    51.8
# male      48.2
# Name: proportion, dtype: float64
#
#
# ...
# VALUE COUNTS FOR: RACE/ETHNICITY
# ...
# race/ethnicity
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: count, dtype: int64
#
# PERCENTAGE DISTRIBUTION:
# race/ethnicity
# group C    31.9
# group D    26.2
# group B    19.0
# group E    14.0
# group A     8.9
# Name: proportion, dtype: float64
#
#
# ...
# VALUE COUNTS FOR: PARENTAL LEVEL OF EDUCATION
# ...
# parental level of education
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: count, dtype: int64
#
# PERCENTAGE DISTRIBUTION:
# parental level of education
# some college          22.6
# associate's degree    22.2
# high school           19.6
# some high school      17.9
# ...

# %%
# Plotting (2x3 grid)
fig, axes = plt.subplots(2, 3, figsize=(18, 10))
axes = axes.flatten()

colors = ['skyblue', 'lightgreen', 'salmon', 'orange', 'violet']

for i, col in enumerate(categorical_cols):
    sns.countplot(data=df, x=col, ax=axes[i], color=colors[i])
    axes[i].set_title(f"{col.title()} Distribution")
    axes[i].set_xlabel(col)
    axes[i].set_ylabel("Count")
    axes[i].tick_params(axis='x', rotation=30)

# Hide unused subplot (6th one)
axes[-1].axis('off')

plt.tight_layout()
plt.show()

# %%
cols = ['math score', 'reading score', 'writing score']
# gender
print("MEAN SCORES BY GENDER")
print("="*60)
gender_means = df.groupby('gender')[cols].mean().round(2)
print(gender_means)

print("="*70)
# race
print("MEAN SCORES BY RACE/ETHNICITY")
print("="*60)
race_means = df.groupby('race/ethnicity')[cols].mean().round(2)
print(race_means)

print("="*70)
print("MEAN SCORES BY PARENTAL EDUCATION")
print("="*60)
parent_means = df.groupby('parental level of education')[cols].mean().round(2)
print(parent_means)

print("="*70)
print("MEAN SCORES BY LUNCH TYPE")
print("="*60)
lunch_means = df.groupby('lunch')[cols].mean().round(2)
print(lunch_means)

print("="*70)
print("MEAN SCORES BY TEST PREP COURSE")
print("="*60)
prep_means = df.groupby('test preparation course')[cols].mean().round(2)
print(prep_means)
# Out:
# MEAN SCORES BY GENDER
# ...
#         math score  reading score  writing score
# gender
# female       63.63          72.61          72.47
# male         68.73          65.47          63.31
# ...
# MEAN SCORES BY RACE/ETHNICITY
# ...
#                 math score  reading score  writing score
# race/ethnicity
# group A              61.63          64.67          62.67
# group B              63.45          67.35          65.60
# group C              64.46          69.10          67.83
# group D              67.36          70.03          70.15
# group E              73.82          73.03          71.41
# ...
# MEAN SCORES BY PARENTAL EDUCATION
# ...
#                              math score  reading score  writing score
# parental level of education
# associate's degree                67.88          70.93          69.90
# bachelor's degree                 69.39          73.00          73.38
# high school                       62.14          64.70          62.45
# ...

# %%
parent_means.plot(kind='bar', figsize=(14,6))

plt.title("Parental Education vs Average Scores")
plt.xlabel("Parental Level of Education")
plt.ylabel("Average Score")
plt.xticks(rotation=45)
plt.legend(title="Subjects")
plt.tight_layout()
plt.show()

# %%
score_cols = ['math score', 'reading score', 'writing score']

# Correlation matrix
print("="*60)
print("CORRELATION MATRIX")
print("="*60)
corr_matrix = df[score_cols].corr()
print(corr_matrix)

# Heatmap
plt.figure(figsize=(6,5))
sns.heatmap(corr_matrix, annot=True, fmt='.2f', cmap='Blues', square=True, linewidths=0.5)

plt.title("Correlation Heatmap of Scores")
plt.show()

# Pearson correlations
math_reading_corr = df['math score'].corr(df['reading score'])
reading_writing_corr = df['reading score'].corr(df['writing score'])

print("\n" + "="*60)
print("PEARSON CORRELATIONS")
print("="*60)
print(f"Math vs Reading: {math_reading_corr:.2f}")
print(f"Reading vs Writing: {reading_writing_corr:.2f}")
# Out:
# ...
# CORRELATION MATRIX
# ...
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000
# ...
# PEARSON CORRELATIONS
# ...
# Math vs Reading: 0.82
# Reading vs Writing: 0.95

# %%
score_cols = ['math score', 'reading score', 'writing score']

# Split groups
completed = df[df['test preparation course'] == 'completed']
none = df[df['test preparation course'] == 'none']

# Mean and Standard Deviation
print("="*60)
print("MEAN SCORES (COMPLETED)")
print("="*60)
completed_mean = completed[score_cols].mean().round(2)
print(completed_mean)

print("\n" + "="*60)
print("MEAN SCORES (NONE)")
print("="*60)
none_mean = none[score_cols].mean().round(2)
print(none_mean)

print("\n" + "="*60)
print("STANDARD DEVIATION (COMPLETED)")
print("="*60)
print(completed[score_cols].std().round(2))

print("\n" + "="*60)
print("STANDARD DEVIATION (NONE)")
print("="*60)
print(none[score_cols].std().round(2))


# Improvement %
print("\n" + "="*60)
print("IMPROVEMENT (%)")
print("="*60)

improvement = ((completed_mean - none_mean) / none_mean * 100).round(2)
print(improvement)

fig, axes = plt.subplots(1, 3, figsize=(18,5))

for i, col in enumerate(score_cols):
    sns.boxplot(x='test preparation course', y=col, data=df, ax=axes[i])
    axes[i].set_title(f"{col.title()} vs Test Prep")
    axes[i].set_xlabel("Test Preparation")
    axes[i].set_ylabel("Score")

plt.tight_layout()
plt.show()
# Out:
# ...
# MEAN SCORES (COMPLETED)
# ...
# math score       69.70
# reading score    73.89
# writing score    74.42
# dtype: float64
#
# ...
# MEAN SCORES (NONE)
# ...
# math score       64.08
# reading score    66.53
# writing score    64.50
# dtype: float64
#
# ...
# STANDARD DEVIATION (COMPLETED)
# ...
# math score       14.44
# reading score    13.64
# writing score    13.38
# dtype: float64
#
# ...
# STANDARD DEVIATION (NONE)
# ...
# math score       15.19
# reading score    14.46
# writing score    15.00
# dtype: float64
#
# ...
# IMPROVEMENT (%)
# ...
# math score        8.77
# reading score    11.06
# writing score    15.38
# dtype: float64

# %%
male = df[df['gender'] == 'male']
female = df[df['gender'] == 'female']

score_cols = ['math score', 'reading score', 'writing score']
fig, axes = plt.subplots(1, 3, figsize=(18,5))

# Math
axes[0].hist(male['math score'], bins=20, alpha=0.6, label='Male')
axes[0].hist(female['math score'], bins=20, alpha=0.6, label='Female')
axes[0].set_title("Math Score by Gender")
axes[0].legend()

# Reading
axes[1].hist(male['reading score'], bins=20, alpha=0.6, label='Male')
axes[1].hist(female['reading score'], bins=20, alpha=0.6, label='Female')
axes[1].set_title("Reading Score by Gender")
axes[1].legend()

# Writing
axes[2].hist(male['writing score'], bins=20, alpha=0.6, label='Male')
axes[2].hist(female['writing score'], bins=20, alpha=0.6, label='Female')
axes[2].set_title("Writing Score by Gender")
axes[2].legend()

plt.tight_layout()
plt.show()


# -----------------------------
# Percentage scoring above 70
# -----------------------------
def percent_above_70(group, col):
    return (group[group[col] > 70].shape[0] / group.shape[0]) * 100

results = []

for col in score_cols:
    results.append([
        col,
        round(percent_above_70(male, col), 2),
        round(percent_above_70(female, col), 2)
    ])

summary_df = pd.DataFrame(results, columns=[
    "Subject", "Male % >70", "Female % >70"
])

print("="*60)
print("PERCENTAGE SCORING ABOVE 70")
print("="*60)
print(summary_df)
# Out:
# ...
# PERCENTAGE SCORING ABOVE 70
# ...
#          Subject  Male % >70  Female % >70
# 0     math score       45.85         32.82
# 1  reading score       38.38         58.30
# 2  writing score       32.16         58.11

# %%
# (a) Total score
df['total_score'] = df['math score'] + df['reading score'] + df['writing score']
# (b) Average score
df['average_score'] = df['total_score'] / 3
# (c) Performance grade function
def assign_grade(avg):
    if avg >= 80:
        return 'A'
    elif avg >= 70:
        return 'B'
    elif avg >= 60:
        return 'C'
    elif avg >= 50:
        return 'D'
    else:
        return 'F'
df['performance_grade'] = df['average_score'].apply(assign_grade)
# (d) High achiever
df['high_achiever'] = df['average_score'] >= 80
# (e) Lowest subject per student
def lowest_subject(row):
    scores = {
        'math': row['math score'],
        'reading': row['reading score'],
        'writing': row['writing score']
    }
    return min(scores, key=scores.get)
df['lowest_subject'] = df.apply(lowest_subject, axis=1)
# -----------------------------
# Show updated dataset
# -----------------------------
print("="*60)
print("UPDATED DATAFRAME (FIRST 10 ROWS)")
print("="*60)
print(df.head(10))

# -----------------------------
# Value counts
# -----------------------------
print("\n" + "="*60)
print("GRADE DISTRIBUTION")
print("="*60)
print(df['performance_grade'].value_counts())
print("\n" + "="*60)
print("LOWEST SUBJECT DISTRIBUTION")
print("="*60)
print(df['lowest_subject'].value_counts())
# Out:
# ...
# UPDATED DATAFRAME (FIRST 10 ROWS)
# ...
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# ...

# %%
cols = ['math score', 'reading score', 'writing score', 'average_score']

# -----------------------------
# Pair Plot 1: Gender
# -----------------------------
g1 = sns.pairplot(
    df[cols + ['gender']],
    hue='gender',
    plot_kws={'alpha': 0.5}
)

g1.fig.suptitle("Pair Plot (Hue: Gender)", y=1.02)
plt.savefig("pairplot_scores.png", dpi=150)
plt.show()


# -----------------------------
# Pair Plot 2: Performance Grade
# -----------------------------
g2 = sns.pairplot(
    df[cols + ['performance_grade']],
    hue='performance_grade',
    plot_kws={'alpha': 0.5}
)

g2.fig.suptitle("Pair Plot (Hue: Performance Grade)", y=1.02)
plt.savefig("pairplot_grades.png", dpi=150)
plt.show()

# %%
# -----------------------------
# Pivot Table 1: Parental Education vs Gender (Average Score)
# -----------------------------
pivot1 = df.pivot_table(
    index='parental level of education',
    columns='gender',
    values='average_score',
    aggfunc='mean'
).round(2)

print("="*60)
print("PIVOT TABLE 1: PARENTAL EDUCATION vs GENDER (AVG SCORE)")
print("="*60)
print(pivot1)

# Heatmap
plt.figure(figsize=(8,5))
sns.heatmap(pivot1, annot=True, cmap='Blues', fmt='.2f', linewidths=0.5)
plt.title("Average Score by Parental Education and Gender")
plt.xlabel("Gender")
plt.ylabel("Parental Education")
plt.show()


# -----------------------------
# Pivot Table 2: Race vs Test Prep (Math Score)
# -----------------------------
pivot2 = df.pivot_table(
    index='race/ethnicity',
    columns='test preparation course',
    values='math score',
    aggfunc='mean'
).round(2)

print("\n" + "="*60)
print("PIVOT TABLE 2: RACE vs TEST PREP (MATH SCORE)")
print("="*60)
print(pivot2)

# Heatmap
plt.figure(figsize=(8,5))
sns.heatmap(pivot2, annot=True, cmap='Greens', fmt='.2f', linewidths=0.5)
plt.title("Math Score by Race/Ethnicity and Test Preparation")
plt.xlabel("Test Preparation")
plt.ylabel("Race/Ethnicity")
plt.show()
# Out:
# ...
# PIVOT TABLE 1: PARENTAL EDUCATION vs GENDER (AVG SCORE)
# ...
# gender                       female   male
# parental level of education
# associate's degree            71.12  67.87
# bachelor's degree             74.67  68.78
# high school                   64.75  61.58
# master's degree               73.65  73.52
# some college                  71.00  65.72
# some high school              65.56  64.64
# ...
# PIVOT TABLE 2: RACE vs TEST PREP (MATH SCORE)
# ...
# test preparation course  completed   none
# race/ethnicity
# group A                      68.26  58.09
# group B                      67.19  61.37
# group C                      67.50  62.71
# group D                      69.79  66.26
# group E                      77.43  71.11

# %%
# -----------------------------
# (a) score_summary
# -----------------------------
def score_summary(df, col):
    """
    Compute summary statistics for a numeric column.

    Parameters:
    df (pd.DataFrame): Input dataframe
    col (str): Column name (numeric)

    Returns:
    dict: {
        'mean', 'median', 'std', 'min', 'max', 'pct_above_70'
    }
    """
    series = df[col].dropna()

    summary = {
        "mean": float(np.mean(series)),
        "median": float(np.median(series)),
        "std": float(np.std(series, ddof=1)),  # sample std
        "min": float(np.min(series)),
        "max": float(np.max(series)),
        "pct_above_70": float((series > 70).sum() / len(series) * 100)
    }
    return summary


# -----------------------------
# (b) plot_distribution
# -----------------------------
def plot_distribution(df, col, color):
    """
    Plot histogram with KDE overlay and mean line.

    Parameters:
    df (pd.DataFrame): Input dataframe
    col (str): Column name (numeric)
    color (str): Color for histogram/KDE
    """
    plt.figure(figsize=(7,5))

    sns.histplot(df[col], kde=True, color=color, bins=20)

    mean_val = df[col].mean()
    plt.axvline(mean_val, color='red', linestyle='--', linewidth=2, label=f"Mean = {mean_val:.2f}")

    plt.title(f"Distribution of {col}")
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.legend()
    plt.tight_layout()
    plt.show()


# -----------------------------
# (c) compare_groups
# -----------------------------
def compare_groups(df, group_col, score_col):
    """
    Compare groups by mean score and percentage above 70.

    Parameters:
    df (pd.DataFrame): Input dataframe
    group_col (str): Column to group by (categorical)
    score_col (str): Numeric score column

    Returns:
    pd.DataFrame: Sorted by mean_score (descending) with:
        [group_col, mean_score, pct_above_70]
    """
    grp = df.groupby(group_col)[score_col]

    result = pd.DataFrame({
        group_col: grp.mean().index,
        "mean_score": grp.mean().values,
        "pct_above_70": grp.apply(lambda x: (x > 70).sum() / len(x) * 100).values
    })

    return result.sort_values(by="mean_score", ascending=False).reset_index(drop=True)


# =====================================================
# FUNCTION CALLS (SHOW OUTPUTS)
# =====================================================

print("="*60)
print("SCORE SUMMARY — MATH")
print("="*60)
print(score_summary(df, 'math score'))

print("\n" + "="*60)
print("SCORE SUMMARY — READING")
print("="*60)
print(score_summary(df, 'reading score'))

print("\n" + "="*60)
print("SCORE SUMMARY — WRITING")
print("="*60)
print(score_summary(df, 'writing score'))


# Plots
plot_distribution(df, 'math score', 'skyblue')
plot_distribution(df, 'reading score', 'green')
plot_distribution(df, 'writing score', 'orange')


# Group comparisons
print("\n" + "="*60)
print("COMPARE GROUPS — GENDER vs MATH")
print("="*60)
print(compare_groups(df, 'gender', 'math score'))

print("\n" + "="*60)
print("COMPARE GROUPS — TEST PREP vs WRITING")
print("="*60)
print(compare_groups(df, 'test preparation course', 'writing score'))
# Out:
# ...
# SCORE SUMMARY — MATH
# ...
# {'mean': 66.089, 'median': 66.0, 'std': 15.163080096009468, 'min': 0.0, 'max': 100.0, 'pct_above_70': 39.1}
#
# ...
# SCORE SUMMARY — READING
# ...
# {'mean': 69.169, 'median': 70.0, 'std': 14.60019193725222, 'min': 17.0, 'max': 100.0, 'pct_above_70': 48.699999999999996}
#
# ...
# SCORE SUMMARY — WRITING
# ...
# {'mean': 68.054, 'median': 69.0, 'std': 15.195657010869642, 'min': 10.0, 'max': 100.0, 'pct_above_70': 45.6}
# ...
# COMPARE GROUPS — GENDER vs MATH
# ...
#    gender  mean_score  pct_above_70
# 0    male   68.728216     45.850622
# 1  female   63.633205     32.818533
#
# ...
# COMPARE GROUPS — TEST PREP vs WRITING
# ...
#   test preparation course  mean_score  pct_above_70
# 0               completed   74.418994     63.128492
# 1                    none   64.504673     35.825545

# %%
import numpy as np

# Extract arrays (after this → ONLY NumPy)
math = df['math score'].values
reading = df['reading score'].values
writing = df['writing score'].values

scores = {
    "Math": math,
    "Reading": reading,
    "Writing": writing
}

# -----------------------------
# (a) Basic statistics
# -----------------------------
print("="*60)
print("NUMPY STATISTICS")
print("="*60)

for name, arr in scores.items():
    print(f"\n{name} Scores:")
    print("Mean:", np.mean(arr))
    print("Median:", np.median(arr))
    print("Std Dev:", np.std(arr))
    print("Variance:", np.var(arr))
    print("Min:", np.min(arr))
    print("Max:", np.max(arr))


# -----------------------------
# (b) Z-score extreme values
# -----------------------------
print("\n" + "="*60)
print("Z-SCORE EXTREMES (|z| > 2)")
print("="*60)

for name, arr in scores.items():
    z = (arr - np.mean(arr)) / np.std(arr)
    extreme_count = np.sum((z > 2) | (z < -2))
    print(f"{name}: {extreme_count} students")


# -----------------------------
# (c) Percentiles table
# -----------------------------
percentiles = [10, 25, 50, 75, 90]

print("\n" + "="*60)
print("PERCENTILES TABLE")
print("="*60)

table = []

for name, arr in scores.items():
    row = [name]
    for p in percentiles:
        row.append(round(np.percentile(arr, p), 2))
    table.append(row)

# Convert to NumPy array for display
table = np.array(table)
print(table)


# -----------------------------
# (d) Top 10 math scorers (index)
# -----------------------------
top10_indices = np.argsort(math)[-10:][::-1]

print("\n" + "="*60)
print("TOP 10 MATH SCORERS (INDICES)")
print("="*60)
print(top10_indices)


# -----------------------------
# (e) Pass rate (>70)
# -----------------------------
print("\n" + "="*60)
print("PASS RATE (>70)")
print("="*60)

for name, arr in scores.items():
    pass_array = (arr > 70).astype(int)
    pass_rate = np.mean(pass_array) * 100
    print(f"{name}: {pass_rate:.2f}%")
# Out:
# ...
# NUMPY STATISTICS
# ...
#
# Math Scores:
# Mean: 66.089
# Median: 66.0
# Std Dev: 15.155496659628149
# Variance: 229.68907899999996
# Min: 0
# Max: 100
#
# Reading Scores:
# Mean: 69.169
# Median: 70.0
# Std Dev: 14.592890015346516
# Variance: 212.95243900000003
# Min: 17
# Max: 100
#
# Writing Scores:
# Mean: 68.054
# Median: 69.0
# Std Dev: 15.188057281956768
# Variance: 230.677084
# Min: 10
# Max: 100
#
# ...
# Z-SCORE EXTREMES (|z| > 2)
# ...
# Math: 46 students
# Reading: 46 students
# Writing: 42 students
#
# ...
# PERCENTILES TABLE
# ...
# [['Math' '47.0' '57.0' '66.0' '77.0' '86.0']
#  ['Reading' '51.0' '59.0' '70.0' '79.0' '87.1']
#  ['Writing' '48.0' '57.75' '69.0' '79.0' '87.0']]
#
# ...
# TOP 10 MATH SCORERS (INDICES)
# ...
# [916 458 962 625 623 451 149 306 114 263]
#
# ...
# PASS RATE (>70)
# ...
# Math: 39.10%
# Reading: 48.70%
# Writing: 45.60%

# %%
score_cols = ['math score', 'reading score', 'writing score']

# Create figure
fig, axes = plt.subplots(3, 2, figsize=(16, 18))
fig.suptitle("📊 Student Performance EDA Dashboard", fontsize=20, fontweight='bold')

# -----------------------------
# (1) Math histogram with KDE (by gender)
# -----------------------------
sns.histplot(data=df, x='math score', hue='gender', kde=True,
             ax=axes[0,0], alpha=0.6)
axes[0,0].set_title("Math Score Distribution by Gender")

# -----------------------------
# (2) Box plot (all subjects)
# -----------------------------
sns.boxplot(data=df[score_cols], ax=axes[0,1])
axes[0,1].set_title("Score Distribution Across Subjects")
axes[0,1].set_ylabel("Scores")

# -----------------------------
# (3) Scatter + regression (Reading vs Writing)
# -----------------------------
sns.scatterplot(data=df, x='reading score', y='writing score',
                hue='test preparation course', ax=axes[1,0], alpha=0.7)

sns.regplot(data=df, x='reading score', y='writing score',
            scatter=False, ax=axes[1,0], color='black')

axes[1,0].set_title("Reading vs Writing (Test Prep Impact)")

# -----------------------------
# (4) Grouped bar (Race vs Scores)
# -----------------------------
race_means = df.groupby('race/ethnicity')[score_cols].mean()
race_means.plot(kind='bar', ax=axes[1,1])
axes[1,1].set_title("Average Scores by Race/Ethnicity")
axes[1,1].set_ylabel("Average Score")
axes[1,1].legend(title="Subjects")

# -----------------------------
# (5) Horizontal bar (Parental Education)
# -----------------------------
parent_means = df.groupby('parental level of education')[score_cols].mean().mean(axis=1)
parent_means = parent_means.sort_values(ascending=True)

parent_means.plot(kind='barh', ax=axes[2,0], color='skyblue')
axes[2,0].set_title("Average Score by Parental Education")

# -----------------------------
# (6) Pie chart (Grade Distribution)
# -----------------------------
grade_counts = df['performance_grade'].value_counts()

axes[2,1].pie(grade_counts,
              labels=grade_counts.index,
              autopct='%1.1f%%',
              startangle=90)

axes[2,1].set_title("Performance Grade Distribution")

# -----------------------------
# Layout + Save
# -----------------------------
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig("eda_dashboard.png", dpi=150)

plt.show()

# %% [markdown]
# # 📊 AI/ML Internship Week 1 — Final Data Analysis Report
#
# ---
#
# ## 1. Executive Summary
#
# This report analyzes a dataset of 1000 students containing demographic attributes and academic performance in math, reading, and writing. The goal is to identify patterns, relationships, and performance differences using statistical analysis, visualization, feature engineering, and NumPy-based computations. The study reveals strong correlations between subjects, clear impact of test preparation, and moderate influence of parental education on student performance. Gender-based differences are also observed, especially in reading and writing. Overall, the dataset is well-structured and suitable for predictive modeling and educational performance analysis.
#
# ---
#
# ## 2. Data Quality Assessment
#
# The dataset is clean, well-structured, and ready for analysis. There are no missing values or duplicate records, which ensures high data reliability. All columns have appropriate data types, with categorical variables stored as objects and numerical variables as integers. This makes preprocessing straightforward for machine learning tasks. If missing values were present, numerical columns would be handled using mean or median imputation, while categorical variables would use mode imputation. Overall, the dataset quality is excellent and does not require major cleaning steps.
#
# ---
#
# ## 3. Key Statistical Findings
#
# The statistical analysis shows that reading and writing scores are slightly higher and more consistent compared to math scores. Mean and median values across subjects are close, indicating relatively symmetric distributions. Standard deviation analysis shows that math has the highest variability, meaning student performance in math is more spread out. Correlation analysis shows a very strong relationship between reading and writing, while math is moderately correlated with both. Percentile analysis confirms that the dataset is evenly distributed without extreme skewness. Overall, students perform best in reading and writing compared to math.
#
# ---
#
# ## 4. Visualization Insights
#
# Visual analysis confirms statistical findings. Histograms show near-normal distributions across all subjects. Box plots indicate that writing and reading have higher medians compared to math. Scatter plots show a strong linear relationship between reading and writing scores, especially among students who completed test preparation. Heatmaps confirm strong correlations among all three subjects. Grouped bar charts show that parental education and test preparation significantly influence performance. Overall, visualizations make patterns clearer and highlight differences between student groups effectively.
#
# ---
#
# ## 5. Feature Engineering Rationale
#
# Several new features were created to enhance analysis. Total score combines all subjects into one performance metric. Average score provides normalized academic performance. Performance grade converts numerical values into categorical labels (A–F) for easier interpretation. High achiever identifies top-performing students, while lowest subject highlights individual weaknesses. These engineered features improve interpretability, support classification tasks, and provide deeper insights into student performance patterns.
#
# ---
#
# ## 6. Actionable Recommendations for Educators
#
# Educators should prioritize improving math performance, as it shows higher variability and lower average scores compared to reading and writing. Test preparation programs should be encouraged since they significantly improve student outcomes across all subjects. Students from lower parental education backgrounds may require additional academic support. Reading and writing should be taught in an integrated manner due to their strong correlation. Early identification of weak students using engineered features like lowest subject can help provide targeted interventions. Personalized learning strategies will improve overall academic performance.
#
# ---
#
# ## 7. Reflection & Lessons Learned
#
# This project strengthened understanding of data analysis using Python, including Pandas, NumPy, Matplotlib, and Seaborn. It demonstrated how raw data can be transformed into meaningful insights through structured steps. Key learning includes the importance of data exploration before modeling, the power of visualization in understanding patterns, and the value of feature engineering in improving analysis quality. This exercise also highlighted how statistical and visual methods complement each other. Overall, it provided strong foundational experience for future machine learning and AI tasks.
#
# ---
#
# # 📌 End of Report
